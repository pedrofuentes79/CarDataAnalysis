# %% [markdown]
# The objective of this notebook is to create a dataset of cars in argentina. These cars are not any cars, but the ones rated by Doug Demuro in his (dataset)[https://www.dougdemuro.com/dougscore]. This is to show the reality of cars in argentina in relation to the rest of the world.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data/dougScore/DougScore.xlsx")
pd.set_option('display.max_colwidth', None)

# %%
df.rename(columns={'Model ': 'Model'}, inplace=True)

# %%
# make sure all columns are strings
df["Model"] = df["Model"].astype(str)
df["Make"] = df["Make"].astype(str)

# %%
# For each of these cars, look them up on MercadoLibre API

import requests
import json

#xD, put it in a environment variable later
token = ""

# send the request
def getCarInfo(car):
    url = "https://api.mercadolibre.com/sites/MLA/search?q=" + car + "&access_token=" + token + "&category=MLA1743"
    response = requests.get(url)
    return response.json()


# test
resp = getCarInfo("toyota supra")["results"]
print(json.dumps(resp, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "accepts_mercadopago": true,
#         "address": {
#             "city_id": "TUxBQ0NBUGZlZG1sYQ",
#             "city_name": "Capital Federal",
#             "state_id": "TUxBUENBUGw3M2E1",
#             "state_name": "Capital Federal"
#         },
#         "attributes": [
#             {
#                 "attribute_group_id": "",
#                 "attribute_group_name": "",
#                 "id": "ITEM_CONDITION",
#                 "name": "Condici\u00f3n del \u00edtem",
#                 "source": 1,
#                 "value_id": "2230581",
#                 "value_name": "Usado",
#                 "value_struct": null,
#                 "value_type": "list",
#                 "values": [
#                     {
#                         "id": "2230581",
#                         "name": "Usado",
#                         "source": 1,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "ADICIONALES",
#                 "attribute_group_name": "Adicionales",
#                 "id": "SINGLE_OWNER",
#                 "name": "\u00danico due\u00f1o",
#                 "source": 3149448506392345,
#                 "value_id": "242084",
#                 "value_name": "No",
#                 "value_struct": null,
#                 "value_type": "boolean",
#                 "values": [
#                     {
#                         "id": "242084",
#                         "name": "No",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "ADICIONALES",
#                 "attribute_group_name": "Adicionales",
#                 "id": "TRACTION_CONTROL",
#                 "name": "Control de tracci\u00f3n",
#                 "source": 1572,
#                 "value_id": "493980",
#                 "value_name": "Trasera",
#                 "value_struct": null,
#                 "value_type": "list",
#                 "values": [
#                     {
#                         "id": "493980",
#                         "name": "Trasera",
#                         "source": 1572,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "CONFORT",
#                 "attribute_group_name": "Confort",
#                 "id": "HAS_AIR_CONDITIONING",
#                 "name": "Aire acondicionado",
#                 "source": 3149448506392345,
#                 "value_id": "242085",
#                 "value_name": "S\u00ed",
#                 "value_struct": null,
#                 "value_type": "boolean",
#                 "values": [
#                     {
#                         "id": "242085",
#                         "name": "S\u00ed",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "DFLT",
#                 "attribute_group_name": "Otros",
#                 "id": "ENGINE_DISPLACEMENT",
#                 "name": "Cilindrada",
#                 "source": 1572,
#                 "value_id": "2326653",
#                 "value_name": "3 L",
#                 "value_struct": {
#                     "number": 3,
#                     "unit": "L"
#                 },
#                 "value_type": "number_unit",
#                 "values": [
#                     {
#                         "id": "2326653",
#                         "name": "3 L",
#                         "source": 1572,
#                         "struct": {
#                             "number": 3,
#                             "unit": "L"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "DFLT",
#                 "attribute_group_name": "Otros",
#                 "id": "LENGTH",
#                 "name": "Largo",
#                 "source": 1572,
#                 "value_id": "488315",
#                 "value_name": "4620 mm",
#                 "value_struct": {
#                     "number": 4620,
#                     "unit": "mm"
#                 },
#                 "value_type": "number_unit",
#                 "values": [
#                     {
#                         "id": "488315",
#                         "name": "4620 mm",
#                         "source": 1572,
#                         "struct": {
#                             "number": 4620,
#                             "unit": "mm"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "DFLT",
#                 "attribute_group_name": "Otros",
#                 "id": "PASSENGER_CAPACITY",
#                 "name": "Capacidad de personas",
#                 "source": 1572,
#                 "value_id": "458560",
#                 "value_name": "2",
#                 "value_struct": null,
#                 "value_type": "number",
#                 "values": [
#                     {
#                         "id": "458560",
#                         "name": "2",
#                         "source": 1572,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "DFLT",
#                 "attribute_group_name": "Otros",
#                 "id": "POWER",
#                 "name": "Potencia",
#                 "source": 1572,
#                 "value_id": "459072",
#                 "value_name": "204 hp",
#                 "value_struct": {
#                     "number": 204,
#                     "unit": "hp"
#                 },
#                 "value_type": "number_unit",
#                 "values": [
#                     {
#                         "id": "459072",
#                         "name": "204 hp",
#                         "source": 1572,
#                         "struct": {
#                             "number": 204,
#                             "unit": "hp"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "BRAND",
#                 "name": "Marca",
#                 "source": 3149448506392345,
#                 "value_id": "60297",
#                 "value_name": "Toyota",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": "60297",
#                         "name": "Toyota",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "DOORS",
#                 "name": "Puertas",
#                 "source": 1572,
#                 "value_id": "60258",
#                 "value_name": "2",
#                 "value_struct": null,
#                 "value_type": "number",
#                 "values": [
#                     {
#                         "id": "60258",
#                         "name": "2",
#                         "source": 1572,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "ENGINE",
#                 "name": "Motor",
#                 "source": 1572,
#                 "value_id": "2164458",
#                 "value_name": "3.0",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": "2164458",
#                         "name": "3.0",
#                         "source": 1572,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "FUEL_TYPE",
#                 "name": "Tipo de combustible",
#                 "source": 3149448506392345,
#                 "value_id": "64364",
#                 "value_name": "Nafta",
#                 "value_struct": null,
#                 "value_type": "list",
#                 "values": [
#                     {
#                         "id": "64364",
#                         "name": "Nafta",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "KILOMETERS",
#                 "name": "Kil\u00f3metros",
#                 "source": 3282472529718136,
#                 "value_id": null,
#                 "value_name": "66000 km",
#                 "value_struct": {
#                     "number": 66000,
#                     "unit": "km"
#                 },
#                 "value_type": "number_unit",
#                 "values": [
#                     {
#                         "id": null,
#                         "name": "66000 km",
#                         "source": 3282472529718136,
#                         "struct": {
#                             "number": 66000,
#                             "unit": "km"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "MODEL",
#                 "name": "Modelo",
#                 "source": 1572,
#                 "value_id": "63998",
#                 "value_name": "Supra",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": "63998",
#                         "name": "Supra",
#                         "source": 1572,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "TRANSMISSION",
#                 "name": "Transmisi\u00f3n",
#                 "source": 3149448506392345,
#                 "value_id": "370877",
#                 "value_name": "Manual",
#                 "value_struct": null,
#                 "value_type": "list",
#                 "values": [
#                     {
#                         "id": "370877",
#                         "name": "Manual",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "TRIM",
#                 "name": "Versi\u00f3n",
#                 "source": 1572,
#                 "value_id": "2187139",
#                 "value_name": "3.0 Coupe",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": "2187139",
#                         "name": "3.0 Coupe",
#                         "source": 1572,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "VEHICLE_YEAR",
#                 "name": "A\u00f1o",
#                 "source": 1572,
#                 "value_id": "458899",
#                 "value_name": "1992",
#                 "value_struct": null,
#                 "value_type": "number",
#                 "values": [
#                     {
#                         "id": "458899",
#                         "name": "1992",
#                         "source": 1572,
#                         "struct": null
#                     }
#                 ]
#             }
#         ],
#         "available_quantity": 1,
#         "buying_mode": "classified",
#         "catalog_listing": false,
#         "catalog_product_id": "MLA15520156",
#         "category_id": "MLA1744",
#         "condition": "used",
#         "currency_id": "USD",
#         "discounts": null,
#         "domain_id": "MLA-CARS_AND_VANS",
#         "id": "MLA1390873433",
#         "installments": null,
#         "inventory_id": null,
#         "listing_type_id": "free",
#         "location": {
#             "address_line": "",
#             "city": {
#                 "id": "TUxBQ0NBUGZlZG1sYQ",
#                 "name": "Capital Federal"
#             },
#             "country": {
#                 "id": "AR",
#                 "name": "Argentina"
#             },
#             "latitude": -34.6159245,
#             "longitude": -58.4406027,
#             "neighborhood": {
#                 "id": "TUxBQkNBQjM4MDda",
#                 "name": "Caballito"
#             },
#             "state": {
#                 "id": "TUxBUENBUGw3M2E1",
#                 "name": "Capital Federal"
#             },
#             "subneighborhood": null,
#             "zip_code": ""
#         },
#         "official_store_id": null,
#         "order_backend": 1,
#         "original_price": null,
#         "permalink": "https://auto.mercadolibre.com.ar/MLA-1390873433-toyota-supra-30-coupe-_JM",
#         "price": 30000,
#         "promotions": [],
#         "sale_price": null,
#         "seller": {
#             "_": false,
#             "car_dealer": false,
#             "car_dealer_logo": "",
#             "id": 113651146,
#             "nickname": "MIKEBACHMANN",
#             "permalink": "http://perfil.mercadolibre.com.ar/MIKEBACHMANN",
#             "real_estate_agency": false,
#             "registration_date": "2015-01-13T09:44:51.000-04:00",
#             "seller_reputation": {
#                 "level_id": null,
#                 "metrics": {
#                     "cancellations": {
#                         "period": "365 days",
#                         "rate": 0,
#                         "value": 0
#                     },
#                     "claims": {
#                         "period": "365 days",
#                         "rate": 0,
#                         "value": 0
#                     },
#                     "delayed_handling_time": {
#                         "period": "365 days",
#                         "rate": 0,
#                         "value": 0
#                     },
#                     "sales": {
#                         "completed": 5,
#                         "period": "365 days"
#                     }
#                 },
#                 "power_seller_status": null,
#                 "transactions": {
#                     "canceled": 0,
#                     "completed": 5,
#                     "period": "historic",
#                     "ratings": {
#                         "negative": 0,
#                         "neutral": 0,
#                         "positive": 1
#                     },
#                     "total": 5
#                 }
#             },
#             "tags": [
#                 "normal",
#                 "credits_profile",
#                 "messages_as_seller"
#             ]
#         },
#         "seller_address": {
#             "address_line": "",
#             "city": {
#                 "id": "TUxBQk1PTjUxOTJa",
#                 "name": "Monserrat"
#             },
#             "comment": "",
#             "country": {
#                 "id": "AR",
#                 "name": "Argentina"
#             },
#             "id": null,
#             "latitude": null,
#             "longitude": null,
#             "state": {
#                 "id": "AR-C",
#                 "name": "Capital Federal"
#             }
#         },
#         "seller_contact": {
#             "area_code": "",
#             "area_code2": "",
#             "contact": "",
#             "email": "",
#             "other_info": "",
#             "phone": "",
#             "phone2": "",
#             "webpage": ""
#         },
#         "shipping": {
#             "benefits": null,
#             "free_shipping": false,
#             "logistic_type": "not_specified",
#             "mode": "not_specified",
#             "promise": null,
#             "store_pick_up": false,
#             "tags": []
#         },
#         "site_id": "MLA",
#         "sold_quantity": 0,
#         "stop_time": "2023-11-01T04:00:00.000Z",
#         "tags": [
#             "dragged_visits"
#         ],
#         "thumbnail": "http://http2.mlstatic.com/D_721128-MLA50127005513_052022-I.jpg",
#         "thumbnail_id": "721128-MLA50127005513_052022",
#         "title": "Toyota Supra 3.0 Coupe",
#         "use_thumbnail_id": true,
#         "winner_item_id": null
#     },
#     {
#         "accepts_mercadopago": true,
#         "address": {
#             "city_id": "TUxBQ0NBUGZlZG1sYQ",
#             "city_name": "Capital Federal",
#             "state_id": "TUxBUENBUGw3M2E1",
#             "state_name": "Capital Federal"
#         },
#         "attributes": [
#             {
#                 "attribute_group_id": "",
#                 "attribute_group_name": "",
#                 "id": "ITEM_CONDITION",
#                 "name": "Condici\u00f3n del \u00edtem",
#                 "source": 1,
#                 "value_id": "2230581",
#                 "value_name": "Usado",
#                 "value_struct": null,
#                 "value_type": "list",
#                 "values": [
#                     {
#                         "id": "2230581",
#                         "name": "Usado",
#                         "source": 1,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "ADICIONALES",
#                 "attribute_group_name": "Adicionales",
#                 "id": "TRACTION_CONTROL",
#                 "name": "Control de tracci\u00f3n",
#                 "source": 3149448506392345,
#                 "value_id": "493980",
#                 "value_name": "Trasera",
#                 "value_struct": null,
#                 "value_type": "list",
#                 "values": [
#                     {
#                         "id": "493980",
#                         "name": "Trasera",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "DFLT",
#                 "attribute_group_name": "Otros",
#                 "id": "ENGINE_DISPLACEMENT",
#                 "name": "Cilindrada",
#                 "source": 3149448506392345,
#                 "value_id": "2326653",
#                 "value_name": "3 L",
#                 "value_struct": {
#                     "number": 3,
#                     "unit": "L"
#                 },
#                 "value_type": "number_unit",
#                 "values": [
#                     {
#                         "id": "2326653",
#                         "name": "3 L",
#                         "source": 3149448506392345,
#                         "struct": {
#                             "number": 3,
#                             "unit": "L"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "DFLT",
#                 "attribute_group_name": "Otros",
#                 "id": "LENGTH",
#                 "name": "Largo",
#                 "source": 3149448506392345,
#                 "value_id": "488315",
#                 "value_name": "4620 mm",
#                 "value_struct": {
#                     "number": 4620,
#                     "unit": "mm"
#                 },
#                 "value_type": "number_unit",
#                 "values": [
#                     {
#                         "id": "488315",
#                         "name": "4620 mm",
#                         "source": 3149448506392345,
#                         "struct": {
#                             "number": 4620,
#                             "unit": "mm"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "DFLT",
#                 "attribute_group_name": "Otros",
#                 "id": "PASSENGER_CAPACITY",
#                 "name": "Capacidad de personas",
#                 "source": 3149448506392345,
#                 "value_id": "458560",
#                 "value_name": "2",
#                 "value_struct": null,
#                 "value_type": "number",
#                 "values": [
#                     {
#                         "id": "458560",
#                         "name": "2",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "DFLT",
#                 "attribute_group_name": "Otros",
#                 "id": "POWER",
#                 "name": "Potencia",
#                 "source": 3149448506392345,
#                 "value_id": "459072",
#                 "value_name": "204 hp",
#                 "value_struct": {
#                     "number": 204,
#                     "unit": "hp"
#                 },
#                 "value_type": "number_unit",
#                 "values": [
#                     {
#                         "id": "459072",
#                         "name": "204 hp",
#                         "source": 3149448506392345,
#                         "struct": {
#                             "number": 204,
#                             "unit": "hp"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "BRAND",
#                 "name": "Marca",
#                 "source": 3149448506392345,
#                 "value_id": "60297",
#                 "value_name": "Toyota",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": "60297",
#                         "name": "Toyota",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "DOORS",
#                 "name": "Puertas",
#                 "source": 3149448506392345,
#                 "value_id": "60258",
#                 "value_name": "2",
#                 "value_struct": null,
#                 "value_type": "number",
#                 "values": [
#                     {
#                         "id": "60258",
#                         "name": "2",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "ENGINE",
#                 "name": "Motor",
#                 "source": 3149448506392345,
#                 "value_id": "2164458",
#                 "value_name": "3.0",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": "2164458",
#                         "name": "3.0",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "FUEL_TYPE",
#                 "name": "Tipo de combustible",
#                 "source": 3149448506392345,
#                 "value_id": "64364",
#                 "value_name": "Nafta",
#                 "value_struct": null,
#                 "value_type": "list",
#                 "values": [
#                     {
#                         "id": "64364",
#                         "name": "Nafta",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "KILOMETERS",
#                 "name": "Kil\u00f3metros",
#                 "source": 3149448506392345,
#                 "value_id": null,
#                 "value_name": "105000 km",
#                 "value_struct": {
#                     "number": 105000,
#                     "unit": "km"
#                 },
#                 "value_type": "number_unit",
#                 "values": [
#                     {
#                         "id": null,
#                         "name": "105000 km",
#                         "source": 3149448506392345,
#                         "struct": {
#                             "number": 105000,
#                             "unit": "km"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "MODEL",
#                 "name": "Modelo",
#                 "source": 3149448506392345,
#                 "value_id": "63998",
#                 "value_name": "Supra",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": "63998",
#                         "name": "Supra",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "TRANSMISSION",
#                 "name": "Transmisi\u00f3n",
#                 "source": 3149448506392345,
#                 "value_id": "370877",
#                 "value_name": "Manual",
#                 "value_struct": null,
#                 "value_type": "list",
#                 "values": [
#                     {
#                         "id": "370877",
#                         "name": "Manual",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "TRIM",
#                 "name": "Versi\u00f3n",
#                 "source": 3149448506392345,
#                 "value_id": "2187139",
#                 "value_name": "3.0 Coupe",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": "2187139",
#                         "name": "3.0 Coupe",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "VEHICLE_YEAR",
#                 "name": "A\u00f1o",
#                 "source": 3149448506392345,
#                 "value_id": "458899",
#                 "value_name": "1992",
#                 "value_struct": null,
#                 "value_type": "number",
#                 "values": [
#                     {
#                         "id": "458899",
#                         "name": "1992",
#                         "source": 3149448506392345,
#                         "struct": null
#                     }
#                 ]
#             }
#         ],
#         "available_quantity": 1,
#         "buying_mode": "classified",
#         "catalog_listing": false,
#         "catalog_product_id": "MLA15520156",
#         "category_id": "MLA1744",
#         "condition": "used",
#         "currency_id": "USD",
#         "discounts": null,
#         "domain_id": "MLA-CARS_AND_VANS",
#         "id": "MLA1524523628",
#         "installments": null,
#         "inventory_id": null,
#         "listing_type_id": "free",
#         "location": {
#             "address_line": "",
#             "city": {
#                 "id": "TUxBQ0NBUGZlZG1sYQ",
#                 "name": "Capital Federal"
#             },
#             "country": {
#                 "id": "AR",
#                 "name": "Argentina"
#             },
#             "latitude": -34.6048651,
#             "longitude": -58.4905535,
#             "neighborhood": {
#                 "id": "TUxBQlZJTDc4MDda",
#                 "name": "Villa del Parque"
#             },
#             "state": {
#                 "id": "TUxBUENBUGw3M2E1",
#                 "name": "Capital Federal"
#             },
#             "subneighborhood": null,
#             "zip_code": ""
#         },
#         "official_store_id": null,
#         "order_backend": 2,
#         "original_price": null,
#         "permalink": "https://auto.mercadolibre.com.ar/MLA-1524523628-toyota-supra-_JM",
#         "price": 13000,
#         "promotions": [],
#         "sale_price": null,
#         "seller": {
#             "_": false,
#             "car_dealer": false,
#             "car_dealer_logo": "",
#             "id": 53781741,
#             "nickname": "DE \u00d1AUPA",
#             "permalink": "http://perfil.mercadolibre.com.ar/DE+%C3%91AUPA",
#             "real_estate_agency": false,
#             "registration_date": "2008-08-27T19:30:33.000-04:00",
#             "seller_reputation": {
#                 "level_id": null,
#                 "metrics": {
#                     "cancellations": {
#                         "period": "60 months",
#                         "rate": 0,
#                         "value": 0
#                     },
#                     "claims": {
#                         "period": "60 months",
#                         "rate": 0,
#                         "value": 0
#                     },
#                     "delayed_handling_time": {
#                         "period": "60 months",
#                         "rate": 0,
#                         "value": 0
#                     },
#                     "sales": {
#                         "completed": 1,
#                         "period": "60 months"
#                     }
#                 },
#                 "power_seller_status": null,
#                 "transactions": {
#                     "canceled": 0,
#                     "completed": 1,
#                     "period": "historic",
#                     "ratings": {
#                         "negative": 0,
#                         "neutral": 0,
#                         "positive": 1
#                     },
#                     "total": 1
#                 }
#             },
#             "tags": [
#                 "normal",
#                 "messages_as_seller"
#             ]
#         },
#         "seller_address": {
#             "address_line": "",
#             "city": {
#                 "id": null,
#                 "name": "C.A.B.A."
#             },
#             "comment": "",
#             "country": {
#                 "id": "AR",
#                 "name": "Argentina"
#             },
#             "id": null,
#             "latitude": null,
#             "longitude": null,
#             "state": {
#                 "id": "AR-C",
#                 "name": "Capital Federal"
#             }
#         },
#         "seller_contact": {
#             "area_code": "",
#             "area_code2": "",
#             "contact": "",
#             "email": "",
#             "other_info": "",
#             "phone": "",
#             "phone2": "",
#             "webpage": ""
#         },
#         "shipping": {
#             "benefits": null,
#             "free_shipping": false,
#             "logistic_type": "not_specified",
#             "mode": "not_specified",
#             "promise": null,
#             "store_pick_up": false,
#             "tags": []
#         },
#         "site_id": "MLA",
#         "sold_quantity": 0,
#         "stop_time": "2023-10-30T04:00:00.000Z",
#         "tags": [
#             "dragged_visits"
#         ],
#         "thumbnail": "http://http2.mlstatic.com/D_676220-MLA70265021313_072023-I.jpg",
#         "thumbnail_id": "676220-MLA70265021313_072023",
#         "title": "Toyota Supra",
#         "use_thumbnail_id": true,
#         "winner_item_id": null
#     },
#     {
#         "accepts_mercadopago": true,
#         "address": {
#             "city_id": "TUxBQ0NBUGZlZG1sYQ",
#             "city_name": "Capital Federal",
#             "state_id": "TUxBUENBUGw3M2E1",
#             "state_name": "Capital Federal"
#         },
#         "attributes": [
#             {
#                 "attribute_group_id": "",
#                 "attribute_group_name": "",
#                 "id": "ITEM_CONDITION",
#                 "name": "Condici\u00f3n del \u00edtem",
#                 "source": 1,
#                 "value_id": "2230581",
#                 "value_name": "Usado",
#                 "value_struct": null,
#                 "value_type": "list",
#                 "values": [
#                     {
#                         "id": "2230581",
#                         "name": "Usado",
#                         "source": 1,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "BRAND",
#                 "name": "Marca",
#                 "source": 7092,
#                 "value_id": "60297",
#                 "value_name": "Toyota",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": "60297",
#                         "name": "Toyota",
#                         "source": 7092,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "DOORS",
#                 "name": "Puertas",
#                 "source": 7092,
#                 "value_id": null,
#                 "value_name": "2",
#                 "value_struct": null,
#                 "value_type": "number",
#                 "values": [
#                     {
#                         "id": null,
#                         "name": "2",
#                         "source": 7092,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "FUEL_TYPE",
#                 "name": "Tipo de combustible",
#                 "source": 7092,
#                 "value_id": "64364",
#                 "value_name": "Nafta",
#                 "value_struct": null,
#                 "value_type": "list",
#                 "values": [
#                     {
#                         "id": "64364",
#                         "name": "Nafta",
#                         "source": 7092,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "KILOMETERS",
#                 "name": "Kil\u00f3metros",
#                 "source": 1505,
#                 "value_id": null,
#                 "value_name": "41000 km",
#                 "value_struct": {
#                     "number": 41000,
#                     "unit": "km"
#                 },
#                 "value_type": "number_unit",
#                 "values": [
#                     {
#                         "id": null,
#                         "name": "41000 km",
#                         "source": 1505,
#                         "struct": {
#                             "number": 41000,
#                             "unit": "km"
#                         }
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "MODEL",
#                 "name": "Modelo",
#                 "source": 1505,
#                 "value_id": null,
#                 "value_name": "Mr2 coupe",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": null,
#                         "name": "Mr2 coupe",
#                         "source": 1505,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "TRIM",
#                 "name": "Versi\u00f3n",
#                 "source": 7092,
#                 "value_id": "2158513",
#                 "value_name": "2.0",
#                 "value_struct": null,
#                 "value_type": "string",
#                 "values": [
#                     {
#                         "id": "2158513",
#                         "name": "2.0",
#                         "source": 7092,
#                         "struct": null
#                     }
#                 ]
#             },
#             {
#                 "attribute_group_id": "FIND",
#                 "attribute_group_name": "Ficha t\u00e9cnica",
#                 "id": "VEHICLE_YEAR",
#                 "name": "A\u00f1o",
#                 "source": 7092,
#                 "value_id": null,
#                 "value_name": "1992",
#                 "value_struct": null,
#                 "value_type": "number",
#                 "values": [
#                     {
#                         "id": null,
#                         "name": "1992",
#                         "source": 7092,
#                         "struct": null
#                     }
#                 ]
#             }
#         ],
#         "available_quantity": 1,
#         "buying_mode": "classified",
#         "catalog_listing": false,
#         "catalog_product_id": null,
#         "category_id": "MLA1744",
#         "condition": "used",
#         "currency_id": "USD",
#         "discounts": null,
#         "domain_id": "MLA-CARS_AND_VANS",
#         "id": "MLA1393505835",
#         "installments": null,
#         "inventory_id": null,
#         "listing_type_id": "free",
#         "location": {
#             "address_line": "",
#             "city": {
#                 "id": "TUxBQ0NBUGZlZG1sYQ",
#                 "name": "Capital Federal"
#             },
#             "country": {
#                 "id": "AR",
#                 "name": "Argentina"
#             },
#             "latitude": -34.6036844,
#             "longitude": -58.3815591,
#             "neighborhood": {},
#             "state": {
#                 "id": "TUxBUENBUGw3M2E1",
#                 "name": "Capital Federal"
#             },
#             "subneighborhood": null,
#             "zip_code": ""
#         },
#         "official_store_id": null,
#         "order_backend": 3,
#         "original_price": null,
#         "permalink": "https://auto.mercadolibre.com.ar/MLA-1393505835-toyota-supra-20-_JM",
#         "price": 27500,
#         "promotions": [],
#         "sale_price": null,
#         "seller": {
#             "_": false,
#             "car_dealer": false,
#             "car_dealer_logo": "",
#             "id": 624005130,
#             "nickname": "AMADOATILIO",
#             "permalink": "http://perfil.mercadolibre.com.ar/AMADOATILIO",
#             "real_estate_agency": false,
#             "registration_date": "2020-08-10T18:46:59.000-04:00",
#             "seller_reputation": {
#                 "level_id": null,
#                 "metrics": {
#                     "cancellations": {
#                         "period": "60 months",
#                         "rate": 0,
#                         "value": 0
#                     },
#                     "claims": {
#                         "period": "60 months",
#                         "rate": 0,
#                         "value": 0
#                     },
#                     "delayed_handling_time": {
#                         "period": "60 months",
#                         "rate": 0,
#                         "value": 0
#                     },
#                     "sales": {
#                         "completed": 0,
#                         "period": "60 months"
#                     }
#                 },
#                 "power_seller_status": null,
#                 "transactions": {
#                     "canceled": 0,
#                     "completed": 0,
#                     "period": "historic",
#                     "ratings": {
#                         "negative": 0,
#                         "neutral": 0,
#                         "positive": 0
#                     },
#                     "total": 0
#                 }
#             },
#             "tags": [
#                 "normal",
#                 "credits_profile",
#                 "messages_as_seller"
#             ]
#         },
#         "seller_address": {
#             "address_line": "",
#             "city": {
#                 "id": "TUxBQ0xBTmJjYzE4",
#                 "name": "Lan\u00fas"
#             },
#             "comment": "",
#             "country": {
#                 "id": "AR",
#                 "name": "Argentina"
#             },
#             "id": null,
#             "latitude": null,
#             "longitude": null,
#             "state": {
#                 "id": "AR-B",
#                 "name": "Buenos Aires"
#             }
#         },
#         "seller_contact": {
#             "area_code": "",
#             "area_code2": "",
#             "contact": "",
#             "email": "",
#             "other_info": "",
#             "phone": "",
#             "phone2": "",
#             "webpage": ""
#         },
#         "shipping": {
#             "benefits": null,
#             "free_shipping": false,
#             "logistic_type": null,
#             "mode": "not_specified",
#             "promise": null,
#             "store_pick_up": false,
#             "tags": []
#         },
#         "site_id": "MLA",
#         "sold_quantity": 0,
#         "stop_time": "2023-11-24T04:00:00.000Z",
#         "tags": [],
#         "thumbnail": "http://http2.mlstatic.com/D_979057-MLA70673274748_072023-I.jpg",
#         "thumbnail_id": "979057-MLA70673274748_072023",
#         "title": "Toyota Supra 2.0",
#         "use_thumbnail_id": true,
#         "winner_item_id": null
#     }
# ]

# %%
arg_df = pd.DataFrame(columns=["Doug", "Make", "Model","Version", "Kilometers", "Engine", "Fuel Type", "Transmission", "Year", "City", "Price", "Currency", "Link"])

# %%
def sameBrand(a, original):

    if original in ["Mercedes-Benz", "Mercedes Benz", "Mercedes - Benz"]:
        return a in ["Mercedes-Benz", "Mercedes Benz", "Mercedes - Benz"]
    else:
        return a.lower() == original.lower()

def isSimilar(a, original):
    '''
    This function checks if the a string is similar to the original string
    '''
    a = a.lower()
    original = original.lower()
    
    if original in a:
        return True
    else:
        # priority check the first word
        a = a.split(" ")
        original = original.split(" ")
        if original[0] in a:
            # check if the rest are >= 0.5 in count
            count = 0
            for i in range(1, len(original)):
                if original[i] in a:
                    count += 1
            return count/len(original) >= 0.5
        else:
            return False

# %%
for row in range(len(df)):
    car = df.loc[row, ["Make", "Model", "Year"]]
    car_str = car["Make"] + " " + car["Model"] + " " + str(car["Year"])
    resp = getCarInfo(car_str)["results"]
    print("Original: ", car_str)
    for j in range(len(resp)):    
        valid_car = True
        for attr in resp[j]["attributes"]:
            # check if attributes coincide with the original car
            if attr["id"] == "BRAND":
                make = attr["value_name"]
            elif attr["id"] == "MODEL":
                model = attr["value_name"]
            elif attr["id"] == "TRIM":
                version = attr["value_name"]
            elif attr["id"] == "KILOMETERS":
                kilometers = attr["value_name"]
            elif attr["id"] == "ENGINE":
                engine_size = attr["value_name"]
            elif attr["id"] == "FUEL_TYPE":
                fuel_type = attr["value_name"]
            elif attr["id"] == "TRANSMISSION":
                transmission = attr["value_name"]
            elif attr["id"] == "VEHICLE_YEAR":
                year = int(attr["value_name"])
        
        

        # CHECKS
        if not sameBrand(make, car["Make"]):
            valid_car = False
        elif not isSimilar(model + " " + version, car["Model"]):
            valid_car = False


        # put this data in arg_df if the car is the same as the original
        if valid_car:
            city = resp[j]["location"]["city"]["name"]
            price = resp[j]["price"]
            currency_id = resp[0]["currency_id"]
            name = resp[j]["title"]
            link = resp[j]["permalink"]

            # append it to the dataframe
            arg_df.loc[len(arg_df)] = {"Doug": car_str, 
                                       "Make": make, "Model": model, "Version": version, 
                                       "Kilometers": kilometers, 
                                       "Engine": engine_size, "Fuel Type": fuel_type, 
                                       "Transmission": transmission, 
                                       "Year": year, 
                                       "City": city, 
                                       "Price": price, "Currency": currency_id, 
                                       "Link": link}
# Out:
# Original:  McLaren Speedtail 2020
# Original:  McLaren F1 1994
# Original:  Lucid Air Dream Edition 2022
# Original:  GMC Hummer EV Pickup 2022
# Original:  Rivian R1T 2021
# Original:  Tesla Model S Plaid 2021
# Original:  Bugatti Divo 2019
# Original:  Bugatti Chiron Pur Sport 2021
# Original:  Bugatti Chiron 2018
# Original:  Ferrari Monza SP1 2020
# Original:  Mercedes AMG E63 Wagon 2021
# Original:  Rimac Nevera 2021
# Original:  Koenigsegg Regera 2021
# Original:  McLaren Sabre 2021
# Original:  Ferrari SF90 Stradale 2021
# Original:  Audi RS6 Avant 2021
# Original:  Porsche Taycan Turbo S 2020
# Original:  Ferrari LaFerrari 2015
# Original:  Mitsubishi Sigma 1990
# Original:  Chevrolet Suburban 1996
# Original:  Buick  Reatta 1989
# Original:  Chevrolet Tahoe Hybrid 2008
# Original:  Saab 2019-09-05 00:00:00 2011
# Original:  Jaguar XJS V12 1988
# Original:  Nissan Titan XD Platinum Reserve 2018
# Original:  Honda Civic EX Sedan 2022
# Original:  Dodge Camper Van 1987
# Original:  Lincoln Blackwood 2002
# Original:  Chrysler PT Cruiser GT 2007
# Original:  Oldsmobile Custom Cruiser 1985
# Original:  Land Rover Evoque Convertible 2017
# Original:  Pontiac Aztek 2004
# Original:  Subaru Sambar Van 1991
# Original:  Smart Crossblade 2003
# Original:  Ford F-650 2016
# Original:  Oldsmobile Silhouette 1996
# Original:  Toyota Corolla Hybrid 2020
# Original:  Rolls-Royce Silver Shadow 1973
# Original:  Lamborghini Jarama GT 1972
# Original:  Cadillac ELR 2015
# Original:  Pontiac Vibe GT 2005
# Original:  Mitsubishi Pajero Mini 1996
# Original:  Ford  Bronco 1996
# Original:  Isuzu VehiCROSS 2001
# Original:  Ford Explorer XLT 1994
# Original:  Dodge Dakota Convertible 1989
# Original:  Volga GAZ 24-10 1988
# Original:  Los Res Car 2016
# Original:  Geo  Metro Convertible 1992
# Original:  Hummer H2 2005
# Original:  Ferret Tank 1975
# Original:  Mitsubishi Mirage 2016
# Original:  Nissan Murano CrossCabriolet 2012
# Original:  Mercedes-Benz Metris 2017
# Original:  Yugo GV 1988
# Original:  Trabant Trabant 1971
# Original:  BMW Isetta 1969

# %%
arg_df.head()
# Out:
#                                   Doug         Make        Model  \
# 0  Lamborghini Huracan Evo Spyder 2020  Lamborghini  Huracan Evo
# 1                Lamborghini Urus 2019  Lamborghini         Urus
# 2             Lamborghini Huracan 2015  Lamborghini  Huracan Evo
# 3          Ferrari F12 Berlinetta 2015      Ferrari          F12
# 4                         Ford GT 2019         Ford      Mustang
#
#               Version Kilometers              Engine Fuel Type  \
# 0  Spyder  Malek Fara    1001 km             V10 5.2     Nafta
# 1          Malek Fara    1001 km    V8 Biturbo 650cv     Nafta
# 2  Spyder  Malek Fara    1001 km             V10 5.2     Nafta
# 3      F12 Berlinetta    3300 km  3.0 V6 Turbo 340CV     Nafta
# 4        5.0 Gt 421cv   10300 km                 5.0     Nafta
#
#             Transmission  Year             City   Price Currency  \
# 0  Automática secuencial  2023  Capital Federal  123321      USD
# 1  Automática secuencial  2023  Capital Federal  123321      USD
# 2  Automática secuencial  2023  Capital Federal  123321      USD
# 3             Automática  2018  Capital Federal  900000      ARS
# 4                 Manual  2019        San Justo   78000      USD
#
#                                                                                                                Link
# 0  https://auto.mercadolibre.com.ar/MLA-1530995974-lamborghini-huracan-evo-spyder-no-ferrari-porsche-malek-fara-_JM
# 1             https://auto.mercadolibre.com.ar/MLA-1393359903-lamborghini-urus-no-ferrari-no-porsche-malek-fara-_JM
# 2  https://auto.mercadolibre.com.ar/MLA-1530995974-lamborghini-huracan-evo-spyder-no-ferrari-porsche-malek-fara-_JM
# 3                                    https://auto.mercadolibre.com.ar/MLA-1527051654-ferrari-f12-f12-berlinetta-_JM
# 4                                 https://auto.mercadolibre.com.ar/MLA-1543098416-ford-mustang-2017-50-gt-421cv-_JM

# %%
arg_df["Price"] = arg_df["Price"].astype(int)
arg_df["Year"] = arg_df["Year"].astype(int)

# %%
# Number of unique dougscore cars
print(len(df))
print(arg_df["Doug"].nunique())
print("Percentage of cars found: ", round(arg_df["Doug"].nunique()/len(df)*100), "%")
# Out:
# 584
# 92
# Percentage of cars found:  16 %

# %%
# look for repeated entries (don't take the link into account)
arg_df[arg_df.duplicated(subset=arg_df.columns[-1], keep=False)].head()
# Out:
#                                   Doug         Make        Model  \
# 0  Lamborghini Huracan Evo Spyder 2020  Lamborghini  Huracan Evo
# 2             Lamborghini Huracan 2015  Lamborghini  Huracan Evo
# 4                         Ford GT 2019         Ford      Mustang
# 5                         Ford GT 2019         Ford      Mustang
# 6       Porsche 911 Turbo S (992) 2021      Porsche          911
#
#               Version Kilometers   Engine Fuel Type           Transmission  \
# 0  Spyder  Malek Fara    1001 km  V10 5.2     Nafta  Automática secuencial
# 2  Spyder  Malek Fara    1001 km  V10 5.2     Nafta  Automática secuencial
# 4        5.0 Gt 421cv   10300 km      5.0     Nafta                 Manual
# 5        5.0 Gt 421cv   22000 km      5.0     Nafta                 Manual
# 6         3.8 Turbo S   77000 km      3.8     Nafta                 Manual
#
#    Year             City   Price Currency  \
# 0  2023  Capital Federal  123321      USD
# 2  2023  Capital Federal  123321      USD
# 4  2019        San Justo   78000      USD
# 5  2017            Pilar   80000      USD
# 6  1998       San Isidro  299000      USD
#
#                                                                                                                Link
# 0  https://auto.mercadolibre.com.ar/MLA-1530995974-lamborghini-huracan-evo-spyder-no-ferrari-porsche-malek-fara-_JM
# 2  https://auto.mercadolibre.com.ar/MLA-1530995974-lamborghini-huracan-evo-spyder-no-ferrari-porsche-malek-fara-_JM
# 4                                 https://auto.mercadolibre.com.ar/MLA-1543098416-ford-mustang-2017-50-gt-421cv-_JM
# 5                                 https://auto.mercadolibre.com.ar/MLA-1530392588-ford-mustang-50-gt-421cv-2019-_JM
# 6                                    https://auto.mercadolibre.com.ar/MLA-1533910398-porsche-911-turbo-930-1980-_JM

# %% [markdown]
# This is somewhat common in MercadoLibre, specially in cars. Some cars have duplicate publications and they have the same specs. These will be deleted from the dataset.

# %%
# delete repeated entries
arg_df = arg_df.drop_duplicates(subset=arg_df.columns[:-1], keep="first")

# %%
# Merge the two datasets. For each entry in the arg_df, add all the columns that correspond to the Doug column

# this will need to be an artificial merge, since the Doug column (in arg_df) is the combination of Make + Model in the df
df["Year"] = df["Year"].astype(str)
# create a "Doug" column on the df that is the combination of Make + Model + Year
df["Doug"] = df["Make"] + " " + df["Model"] + " " + df["Year"]
# change \n to " "
df["Doug"] = df["Doug"].str.replace("\n", " ")

merged_df = pd.merge(arg_df, df, on="Doug", how="left")

# %%
merged_df.to_csv("ArgentinaCars.csv", index=False)
